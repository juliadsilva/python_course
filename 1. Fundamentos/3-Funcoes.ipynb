# %% [markdown]
# ### Funções Built-in

# %% [markdown]
# As funções built-in do Python são aquelas que já vêm "de fábrica" com o interpretador. Isso significa que você não precisa importar nenhum módulo ou instalar bibliotecas externas para usá-las; elas estão sempre disponíveis globalmente no seu código.
#
# | Categoria | Funções Comuns | O que fazem? |
# | --------- | --------- | --------- |
# |Entrada/Saída|```print()```, ```input()```|Exibem dados no console ou recebem dados do usuário.
# |Conversão|```int()```, ```str()```, ```list()```|Transformam um valor de um tipo para outro.
# |Matemática|```abs()```, ```round()```, ```sum()```|Calculam valor absoluto, arredondamento ou soma de sequências.|
# |Informação|```len()```, ```type()```, ```help()```|Retornam o tamanho de um objeto, seu tipo ou abrem a documentação.|

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %% [markdown]
# ### Variáveis Locais e Globais

# %% [markdown]
# - Variáveis Globais: Uma variável global é definida no corpo principal do código, fora de qualquer função, **pode ser vista e acessada de qualquer lugar do seu script**.
# - Variáveis Locais: Uma variável local é criada dentro de uma função, **só quem está dentro daquela função sabe que ela existe**. Assim que a função termina de executar, a variável local é destruída e a memória é liberada.

# %%
def check_namespace():
    z = 13
    print(f'valoz de z = {z}')

# %%
def check_namespace2(z):
    print(f'valoz de z = {z}')

# %%
z = 10

# %%
check_namespace()
# Out:
# valoz de z = 13

# %%
check_namespace2(z)
# Out:
# valoz de z = 15

# %%
def check_namespace3():
    print(f'valor de z é {z1}')
    # E se for z?

# %%
check_namespace3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 check_namespace3()
#
# Cell In[21], line 2, in check_namespace3()
#       1 def check_namespace3():
# ----> 2     print(f'valor de z é {z1}')
#
# NameError: name 'z1' is not defined

# %%
def externa():
    x = 20
    def interna():
        x = 30
        print(f'x={x}')
    interna()
    print(f'x={x}')

# %% [markdown]
# Qual será o resultado apresentaado da célula a seguir?

# %%
x = 10
externa()
print(f'x={x}')
# Out:
# x=30
# x=20
# x=10

# %% [markdown]
# ### Argumentos

# %%
# Podemos ter argumentos default
def nome_pessoa(nome, sobrenome = "Kamada"): 
    print(f'{nome} - {sobrenome}')

# %%
nome_pessoa("Carolina")
# Out:
# Carolina - Kamada

# %% [markdown]
# **args** : argumentos sem palavra chave. Permite flexibilidade de argumento

# %%
def nome_pessoa(*args):
    print(f'{args}')
    print(type(args))

# %%
nome_pessoa(["Carolina", "Silva", "Kamada"])
# Out:
# (['Carolina', 'Silva', 'Kamada'],)
# <class 'tuple'>

# %%
nome_pessoa("Carolina", 12, [1,2,3])
# Out:
# ('Carolina', 12, [1, 2, 3])
# <class 'tuple'>

# %% [markdown]
# **kwargs** : argumentos com palavra chave. Facilita o uso de um argumento específico

# %%
def nome_pessoa(**kwargs):
    print(kwargs.keys())
    #print(f'idade:{kwargs["idade"]}, nome:{kwargs['nome']}')
    # Especialmente útil em conjunto com gerenciamento de exceção

# %%
nome_pessoa(idade=34, tel=44748)
# Out:
# dict_keys(['idade', 'tel'])

# %% [markdown]
# ### Anotações

# %% [markdown]
# São uma funcionalidade introduzida no Python 3.5 (PEP 484) que permite especificar o tipo esperado de uma variável, parâmetro de função ou valor de retorno, **sem causar erros ou exceções**.

# %%
def nome_pessoa(nome:str, idade:int) -> str:
    str_retorno = f'{nome} tem {idade} anos.'
    return str_retorno

# %%
print(nome_pessoa("Carolina", 35))
# Out:
# Carolina tem hh anos.

# %% [markdown]
# Resgatando as anotações

# %%
nome_pessoa.__annotations__
# Out:
# {'nome': str, 'idade': int, 'return': str}

# %%
import pandas as pd
pd.read_csv.__annotations__
# Out:
# {'filepath_or_buffer': 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#  'sep': 'str | None | lib.NoDefault',
#  'delimiter': 'str | None | lib.NoDefault',
#  'header': "int | Sequence[int] | None | Literal['infer']",
#  'names': 'Sequence[Hashable] | None | lib.NoDefault',
#  'index_col': 'IndexLabel | Literal[False] | None',
#  'usecols': 'UsecolsArgType',
#  'dtype': 'DtypeArg | None',
#  'engine': 'CSVEngine | None',
#  'converters': 'Mapping[Hashable, Callable] | None',
#  'true_values': 'list | None',
#  'false_values': 'list | None',
#  'skipinitialspace': 'bool',
#  'skiprows': 'list[int] | int | Callable[[Hashable], bool] | None',
#  'skipfooter': 'int',
#  'nrows': 'int | None',
#  'na_values': 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None',
#  'keep_default_na': 'bool',
#  'na_filter': 'bool',
#  'verbose': 'bool | lib.NoDefault',
#  'skip_blank_lines': 'bool',
#  'parse_dates': 'bool | Sequence[Hashable] | None',
# ...

# %% [markdown]
# ### Docstrings

# %%
def nome_pessoa(nome:str, idade:int) -> str:
    """Esta função é um exemplo do uso de docstring"""
    print(f'{nome} tem {idade} anos.')

# %%
nome_pessoa.__doc__
# Out:
# 'Esta função é um exemplo do uso de docstring'

# %%
pd.read_csv.__doc__
# Out:
# '\nRead a comma-separated values (csv) file into DataFrame.\n\nAlso supports optionally iterating or breaking of the file\ninto chunks.\n\nAdditional help can be found in the online docs for\n`IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.\n\nParameters\n----------\nfilepath_or_buffer : str, path object or file-like object\n    Any valid string path is acceptable. The string could be a URL. Valid\n    URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is\n    expected. A local file could be: file://localhost/path/to/table.csv.\n\n    If you want to pass in a path object, pandas accepts any ``os.PathLike``.\n\n    By file-like object, we refer to objects with a ``read()`` method, such as\n    a file handle (e.g. via builtin ``open`` function) or ``StringIO``.\nsep : str, default \',\'\n    Character or regex pattern to treat as the delimiter. If ``sep=None``, the\n    C engine cannot automatically detect\n    the separator, but the Py
# ...

# %% [markdown]
# ### Importando funções

# %%
#import assets.python_file as pf
from assets.python_file import nome_importado, nome_pessoa_externo

# %%
nome_pessoa_externo("Carolina", 34)
# Out:
# Carolina tem 34 anos.

# %% [markdown]
# ### Funções Lambda

# %% [markdown]
# São funções anônimas são uma forma compacta de criar funções pequenas e descartáveis em Python sem a necessidade de usar a palavra-chave ```def```.
# <br>
# **Quando usar Lambdas?**
# <br>
# As funções lambda são especialmente úteos quando você precisa passar uma função como argumento para outra função (Higher-Order Functions). Os casos mais comuns são com ```map()```, ```filter()``` e ```sorted()``` e list comprehension

# %%
soma_2 = lambda x: x+2
print(soma_2(5))
# Out:
# 7

# %%
# É possível ser utilizada com múltiplos argumentos
soma2_2 = lambda x,y: x+2+y 
print(soma2_2(5,3))
# Out:
# 10

# %% [markdown]
# Combinação com outras funções

# %%
lista = [1,2,3,4,5,6]

# %% [markdown]
# Map

# %%
lista_sqrt = map(lambda x: x*2, lista)
list(lista_sqrt)
# Out:
# [2, 4, 6, 8, 10, 12]

# %% [markdown]
# Filter

# %%
pares_lst = filter(lambda x: x%2 == 0, lista)
list(pares_lst)

# %% [markdown]
# Sorted

# %%
funcionarios = [
    ('Vitor', 5200),
    ("Alice", 4500),
    ("Bob", 3200),
    ("Carlos", 5800),
    ("Diana", 2900)
]

# %%
# Ordenando pelo salário (índice 1 da tupla)
# A lambda diz: "Para cada 'f', use 'f[1]' como critério"
ordenados_por_salario = sorted(funcionarios, key=lambda f: f[1])
print(ordenados_por_salario)
# Out:
# [('Diana', 2900), ('Bob', 3200), ('Alice', 4500), ('Vitor', 5200), ('Carlos', 5800)]

# %% [markdown]
# List comprehension

# %%
[(lambda x: x**2) (x) for x in lista]
# Out:
# [1, 4, 9, 16, 25, 36]
